# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

import plotly.plotly as py
import plotly.figure_factory as ff

# %%
df = pd.read_csv('E:\\abt_app.csv')

# %%
df.head()
# Out:
#   cid\taid\tproduct\tperiod\tact_age\tact_cc\tact_loaninc\tapp_income\tapp_loan_amount\tapp_n_installments\tapp_number_of_children\tapp_spendings\tapp_installment\tapp_char_branch\tapp_char_gender\tapp_char_job_code\tapp_char_marital_status\tapp_char_city\tapp_char_home_status\tapp_char_cars\tact_call_cc\tact_cins_n_loan\tact_ccss_n_loan\tact_call_n_loan\tact_cins_seniority\tact_cins_min_seniority\tact_cins_n_loans_hist\tact_cins_n_statC\tact_cins_n_statB\tact_cins_n_loans_act\tact_cins_maxdue\tact_cins_min_pninst\tact_cins_min_lninst\tact_cins_utl\tact_cins_dueutl\tact_cins_cc\tact_ccss_seniority\tact_ccss_min_seniority\tact_ccss_n_loans_hist\tact_ccss_n_statC\tact_ccss_n_statB\tact_ccss_n_loans_act\tact_ccss_maxdue\tact_ccss_min_pninst\tact_ccss_min_lninst\tact_ccss_utl\tact_ccss_dueutl\tact_ccss_cc\tact_cus_active\tagr3_Mean_CMaxI_Days\tags3_Mean_CMaxI_Days\tagr3_Max_CMaxI_Days\tags3_Max_CMaxI_Days\tagr3_Min_CMaxI_Days\tags3_Min_CMaxI_Days\tagr3_Mean_CMaxI_Due\tags3_Mean_CMaxI_Due
# ...

# %%
list(df)
# Out:
# ['cid\taid\tproduct\tperiod\tact_age\tact_cc\tact_loaninc\tapp_income\tapp_loan_amount\tapp_n_installments\tapp_number_of_children\tapp_spendings\tapp_installment\tapp_char_branch\tapp_char_gender\tapp_char_job_code\tapp_char_marital_status\tapp_char_city\tapp_char_home_status\tapp_char_cars\tact_call_cc\tact_cins_n_loan\tact_ccss_n_loan\tact_call_n_loan\tact_cins_seniority\tact_cins_min_seniority\tact_cins_n_loans_hist\tact_cins_n_statC\tact_cins_n_statB\tact_cins_n_loans_act\tact_cins_maxdue\tact_cins_min_pninst\tact_cins_min_lninst\tact_cins_utl\tact_cins_dueutl\tact_cins_cc\tact_ccss_seniority\tact_ccss_min_seniority\tact_ccss_n_loans_hist\tact_ccss_n_statC\tact_ccss_n_statB\tact_ccss_n_loans_act\tact_ccss_maxdue\tact_ccss_min_pninst\tact_ccss_min_lninst\tact_ccss_utl\tact_ccss_dueutl\tact_ccss_cc\tact_cus_active\tagr3_Mean_CMaxI_Days\tags3_Mean_CMaxI_Days\tagr3_Max_CMaxI_Days\tags3_Max_CMaxI_Days\tagr3_Min_CMaxI_Days\tags3_Min_CMaxI_Days\tagr3_Mean_CMaxI_Due\tags3_Mean_CMaxI_Due
# ...

# %%
df = pd.read_csv('E:\\abt_app.csv', sep='\t')

# %%
delete=['aid','cid','period','default3','default6','default9','default_cross6','default_cross9','default_cross12','default_cross3','cross_aid']

# %%
df=df.drop(delete,axis=1)

# %%
df.head()
# Out:
#   product  act_age    act_cc  act_loaninc  app_income  app_loan_amount  \
# 0     css     45.0  0.326905     1.530456      3267.0           5000.0
# 1     css     42.0  0.538908     2.903600      1722.0           5000.0
# 2     css     59.0  0.543742     3.364738      1486.0           5000.0
# 3     css     63.0  0.587702     3.236246      1545.0           5000.0
# 4     css     48.0  0.436407     1.506932      3318.0           5000.0
#
#    app_n_installments  app_number_of_children  app_spendings  app_installment  \
# 0                24.0                     3.0          860.0            208.0
# 1                24.0                     1.0          720.0            208.0
# 2                24.0                     2.0          600.0            208.0
# 3                24.0                     0.0          700.0            208.0
# 4                24.0                     2.0         1240.0            208.0
#
#              ...            ags12_Min_CMaxA_Due act12_n_arrears  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11437 entries, 0 to 11436
# Columns: 208 entries, product to cross_app_n_installments
# dtypes: float64(199), object(9)
# memory usage: 18.1+ MB

# %%
df.describe()
# Out:
#             act_age        act_cc   act_loaninc    app_income  \
# count  11437.000000  11437.000000  11437.000000  11437.000000
# mean      62.945703      0.573563      4.537371   1689.843578
# std       10.841513      0.195650      3.117308   1270.424921
# min       25.000000      0.065157      0.316857    300.000000
# 25%       55.000000      0.444740      2.392344    868.000000
# 50%       63.000000      0.570302      3.396739   1472.000000
# 75%       70.000000      0.687358      5.760369   2090.000000
# max       92.000000      1.295238     16.666667  15780.000000
#
#        app_loan_amount  app_n_installments  app_number_of_children  \
# count          11437.0             11437.0            11437.000000
# mean            5000.0                24.0                0.678849
# std                0.0                 0.0                0.889654
# min             5000.0                24.0                0.000000
# 25%             5000.0                24.0                0.000000
# ...

# %%
a=df.describe()

# %%
a.boxplot()

# %%
print(df.shape)
# Out:
# (11437, 208)

# %%
df.head()
# Out:
#   product  act_age    act_cc  act_loaninc  app_income  app_loan_amount  \
# 0     css     45.0  0.326905     1.530456      3267.0           5000.0
# 1     css     42.0  0.538908     2.903600      1722.0           5000.0
# 2     css     59.0  0.543742     3.364738      1486.0           5000.0
# 3     css     63.0  0.587702     3.236246      1545.0           5000.0
# 4     css     48.0  0.436407     1.506932      3318.0           5000.0
#
#    app_n_installments  app_number_of_children  app_spendings  app_installment  \
# 0                24.0                     3.0          860.0            208.0
# 1                24.0                     1.0          720.0            208.0
# 2                24.0                     2.0          600.0            208.0
# 3                24.0                     0.0          700.0            208.0
# 4                24.0                     2.0         1240.0            208.0
#
#              ...            ags12_Min_CMaxA_Due act12_n_arrears  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       product  act_age    act_cc  act_loaninc  app_income  app_loan_amount  \
# 0         css     45.0  0.326905     1.530456      3267.0           5000.0
# 1         css     42.0  0.538908     2.903600      1722.0           5000.0
# 2         css     59.0  0.543742     3.364738      1486.0           5000.0
# 3         css     63.0  0.587702     3.236246      1545.0           5000.0
# 4         css     48.0  0.436407     1.506932      3318.0           5000.0
# 5         css     49.0  0.220888     3.001200      1666.0           5000.0
# 6         css     51.0  0.783217     3.885004      1287.0           5000.0
# 7         css     55.0  0.622222     5.291005       945.0           5000.0
# 8         css     60.0  0.634170     2.461841      2031.0           5000.0
# 9         css     60.0  0.620979     3.496503      1430.0           5000.0
# 10        css     57.0  0.387777     5.268704       949.0           5000.0
# ...

# %%
df.select_dtypes(include=['object']).head()
# Out:
#   product app_char_branch app_char_gender app_char_job_code  \
# 0     css           Empty          Female         Permanent
# 1     css           Empty            Male         Permanent
# 2     css           Empty          Female           Retired
# 3     css           Empty          Female           Retired
# 4     css           Empty          Female     Owner company
#
#   app_char_marital_status app_char_city app_char_home_status app_char_cars  \
# 0                  Maried           Big                Owner         Owner
# 1                  Maried           Big               Rental         Owner
# 2                  Maried           Big                Owner         Owner
# 3                Divorced           Big                Owner         Owner
# 4                  Maried           Big                Owner         Owner
#
#   decision
# 0        A
# 1        A
# 2        A
# 3        A
# 4        A

# %%
df2 = df.groupby('app_char_job_code')
df2.describe()
# Out:
#                   act12_n_arrears                                          \
#                             count      mean       std  min  25%  50%  75%
# app_char_job_code
# Contract                    330.0  3.357576  3.253152  0.0  0.0  3.0  6.0
# Owner company               557.0  3.538600  3.507038  0.0  0.0  3.0  6.0
# Permanent                  2732.0  3.849927  3.613741  0.0  0.0  3.0  7.0
# Retired                    7818.0  3.711307  3.494937  0.0  0.0  3.0  6.0
#
#                         act12_n_arrears_days           ...  cross_response  \
#                     max                count      mean ...             75%
# app_char_job_code                                      ...
# Contract           12.0                330.0  0.112121 ...             0.0
# Owner company      12.0                557.0  0.093357 ...             0.0
# Permanent          12.0               2732.0  0.130673 ...             1.0
# ...

# %%
df2 = df.groupby('app_char_city')
df2.describe()
# Out:
#               act12_n_arrears                                                \
#                         count      mean       std  min  25%  50%  75%   max
# app_char_city
# Big                    4021.0  3.769212  3.520156  0.0  0.0  3.0  6.0  12.0
# Large                  1661.0  4.088501  3.644437  0.0  0.0  4.0  7.0  12.0
# Medium                 3811.0  3.675413  3.500337  0.0  0.0  3.0  6.0  12.0
# Small                  1944.0  3.424897  3.411934  0.0  0.0  3.0  6.0  12.0
#
#               act12_n_arrears_days           ...  cross_response       \
#                              count      mean ...             75%  max
# app_char_city                                ...
# Big                         4021.0  0.126585 ...             1.0  1.0
# Large                       1661.0  0.157134 ...             1.0  1.0
# Medium                      3811.0  0.117817 ...             1.0  1.0
# Small                       1944.0  0.097222 ...             1.0  1.0
#
# ...

# %%
df2 = df.groupby('app_char_home_status')
df2.describe()
# Out:
#                      act12_n_arrears                                          \
#                                count      mean       std  min  25%  50%  75%
# app_char_home_status
# Owner                        10217.0  3.751003  3.518112  0.0  0.0  3.0  6.0
# Rental                        1219.0  3.513536  3.517086  0.0  0.0  3.0  6.0
# With parents                     1.0  5.000000       NaN  5.0  5.0  5.0  5.0
#
#                            act12_n_arrears_days           ...  cross_response  \
#                        max                count      mean ...             75%
# app_char_home_status                                      ...
# Owner                 12.0              10217.0  0.124205 ...             1.0
# Rental                12.0               1219.0  0.114028 ...             1.0
# With parents           5.0                  1.0  0.000000 ...             0.0
#
#                           default12                                          \
# ...

# %%
df2 = df.groupby('app_char_cars')
df2.describe()
# Out:
#               act12_n_arrears                                                \
#                         count      mean       std  min  25%  50%  75%   max
# app_char_cars
# No                     1432.0  3.192039  3.364029  0.0  0.0  2.0  5.0  12.0
# Owner                 10005.0  3.802199  3.533604  0.0  0.0  3.0  6.0  12.0
#
#               act12_n_arrears_days           ...  cross_response       \
#                              count      mean ...             75%  max
# app_char_cars                                ...
# No                          1432.0  0.113128 ...             1.0  1.0
# Owner                      10005.0  0.124538 ...             1.0  1.0
#
#               default12
#                   count      mean       std  min  25%  50%  75%  max
# app_char_cars
# No               1277.0  0.444792  0.497137  0.0  0.0  0.0  1.0  1.0
# Owner            8584.0  0.497204  0.500021  0.0  0.0  0.0  1.0  1.0
#
# [2 rows x 1592 columns]

# %%
df.loc[df['app_char_gender'] == 'Male', 'app_char_gender'] = 0
df.loc[df['app_char_gender'] == 'Female', 'app_char_gender'] = 1


df.loc[df['app_char_job_code'] == 'Contract', 'app_char_job_code'] = 0
df.loc[df['app_char_job_code'] == 'Owner company', 'app_char_job_code'] = 1
df.loc[df['app_char_job_code'] == 'Permanent', 'app_char_job_code'] = 2
df.loc[df['app_char_job_code'] == 'Retired', 'app_char_job_code'] = 3


df.loc[df['app_char_marital_status'] == 'Divorced', 'app_char_marital_status'] = 0
df.loc[df['app_char_marital_status'] == 'Maried', 'app_char_marital_status'] = 1
df.loc[df['app_char_marital_status'] == 'Singiel', 'app_char_marital_status'] = 2
df.loc[df['app_char_marital_status'] == 'Widowed', 'app_char_marital_status'] = 3


df.loc[df['app_char_city'] == 'Big', 'app_char_city'] = 0
df.loc[df['app_char_city'] == 'Large', 'app_char_city'] = 1
df.loc[df['app_char_city'] == 'Medium', 'app_char_city'] = 2
df.loc[df['app_char_city'] == 'Small', 'app_char_city'] = 3


df.loc[df['app_char_home_status'] == 'Owner', 'app_char_home_status'] = 0
df.loc[df['app_char_home_status'] == 'Rental', 'app_char_home_status'] = 1
df.loc[df['app_char_home_status'] == 'With parents', 'app_char_home_status'] = 2


df.loc[df['app_char_cars'] == 'No', 'app_char_cars'] = 0
df.loc[df['app_char_cars'] == 'Owner', 'app_char_cars'] = 1

# %%
df = df.loc[:, (df != df.iloc[0]).any()]
df.shape
# Out:
# (11437, 201)

# %%
df.isna().any()
# Out:
# act_age                     False
# act_cc                      False
# act_loaninc                 False
# app_income                  False
# app_number_of_children      False
# app_spendings               False
# app_char_gender             False
# app_char_job_code           False
# app_char_marital_status     False
# app_char_city               False
# app_char_home_status        False
# app_char_cars               False
# act_call_cc                 False
# act_cins_n_loan             False
# act_ccss_n_loan             False
# act_call_n_loan             False
# act_cins_seniority          False
# act_cins_min_seniority      False
# act_cins_n_loans_hist       False
# act_cins_n_statC            False
# act_cins_n_statB            False
# act_cins_n_loans_act         True
# act_cins_maxdue              True
# act_cins_min_pninst          True
# act_cins_min_lninst          True
# act_cins_utl                 True
# act_cins_dueutl              True
# ...

# %%
df_mean = df.fillna(value = df.mean())

df_mean = df_mean.drop('default12', axis = 1)
target = df['default12']

# %%
X_train, X_test, y_train, y_test=train_test_split(df_mean, target)

# %%
cls=KNeighborsClassifier(3)

# %%
exchange = pd.Series(np.random.randint(0,1, size = 11437))
exchange2 = pd.Series(np.random.randint(0,1, size = 11437))

y_train = y_train.fillna(value = exchange)
y_test = y_test.fillna(value = exchange2)

# %%
cls.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
y_pred=cls.predict(X_test)
y_pred
# Out:
# array([1., 0., 1., ..., 0., 1., 1.])
