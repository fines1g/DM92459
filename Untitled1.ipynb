# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\01_heights_weights_genders.csv')

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-c5d84736ba45> in <module>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# 5       Male  67.253016  152.212156
# 6       Male  68.785081  183.927889
# 7       Male  68.348516  167.971110
# 8       Male  67.018950  175.929440
# 9       Male  63.456494  156.399676
# 10      Male  71.195382  186.604926
# 11      Male  71.640805  213.741169
# 12      Male  64.766329  167.127461
# 13      Male  69.283070  189.446181
# 14      Male  69.243732  186.434168
# 15      Male  67.645620  172.186930
# 16      Male  72.418317  196.028506
# 17      Male  63.974326  172.883470
# 18      Male  69.640060  185.983958
# 19      Male  67.936005  182.426648
# 20      Male  67.915050  174.115929
# 21      Male  69.439440  197.731422
# 22      Male  66.149132  149.173566
# 23      Male  75.205974  228.761781
# 24      Male  67.893196  162.006652
# ...

# %%
data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-cf59efe83ac3> in <module>()
# ----> 1 data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size')
#
# ...

# %%
data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv')

# %%
data
# Out:
#    ;"Gender";"FSIQ";"VIQ";"PIQ";"Weight";"Height";"MRI_Count"
# 0          1;"Female";133;132;124;"118";"64.5";816932
# 1             2;"Male";140;150;124;".";"72.5";1001121
# 2           3;"Male";139;123;150;"143";"73.3";1038437
# 3            4;"Male";133;129;128;"172";"68.8";965353
# 4          5;"Female";137;132;134;"147";"65.0";951545
# 5            6;"Female";99;90;110;"146";"69.0";928799
# 6          7;"Female";138;136;131;"138";"64.5";991305
# 7             8;"Female";92;90;98;"175";"66.0";854258
# 8               9;"Male";89;93;84;"134";"66.3";904858
# 9           10;"Male";133;114;147;"172";"68.8";955466
# 10        11;"Female";132;129;124;"118";"64.5";833868
# 11         12;"Male";141;150;128;"151";"70.0";1079549
# 12          13;"Male";135;129;124;"155";"69.0";924059
# 13        14;"Female";140;120;147;"155";"70.5";856472
# 14          15;"Female";96;100;90;"146";"66.0";878897
# 15           16;"Female";83;71;96;"135";"68.0";865363
# ...

# %%
    data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv')sep=';',na_values="."
# Out:
#   File "<ipython-input-24-02041626a958>", line 1
#     data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv')sep=';',na_values="."
#                                                                               ^
# SyntaxError: invalid syntax

# %%
    data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv',    data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv')sep=';',na_values="." )
# Out:
#   File "<ipython-input-25-d50190d5d6f8>", line 1
#     data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv',    data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv')sep=';',na_values="." )
#                                                                                                                                                           ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv'sep=';',na_values=".")
# Out:
#   File "<ipython-input-26-a299a57fe4ab>", line 1
#     data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv'sep=';',na_values=".")
#                                                                              ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv('C:\\Users\\92459\\Desktop\\DM92459\\brain_size.csv'sep=';',na_values=".")
